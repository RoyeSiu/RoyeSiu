# %%
import numpy as np

# %%
features = np.array([1,2])

# %%
features.shape
# Out:
# (2,)

# %%
w = np.array([3,4])
w = features.reshape(1,2)
w.shape
# Out:
# (1, 2)

# %%
from sklearn.linear_model import Perceptron

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])
model = Perceptron()
model.fit(X,y)
model.score(X,y)
model.predict([[0,1]])
# Out:
# array([0])

# %%
a= [[1,2],[3,4]]
type(a)

a= np.array([[1,2],[3,4]])
a.shape
a
a.dot(a.T)
# Out:
# array([[ 5, 11],
#        [11, 25]])

# %%
np.array??

# %%
demand = np.array([[8,1],[5,5],[2,7]])
prices = np.array([[10,5],[8,10]])
np.dot(demand,prices)
# Out:
# array([[88, 50],
#        [90, 75],
#        [76, 80]])
